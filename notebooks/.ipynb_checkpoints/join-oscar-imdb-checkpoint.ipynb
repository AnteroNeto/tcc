# %%
import os
import pandas as pd
#from pandas_profiling import ProfileReport
import seaborn as sns
import matplotlib.pyplot as plt


# %matplotlib inline
#conda install -c conda-forge pandas-profiling
#ProfileReport(df_imdb_oscar, title='Join Oscar Imdb Profiling Report')

# %%
os.chdir("../tratados")
os.getcwd()
# Out:
# '/home/antero/Documentos/TCC/tratados'

# %%
df_imdb = pd.read_csv('df_imdb_tratado.csv', sep=',', na_values='\\N', low_memory=False)

# %%
df_imdb.head()
# Out:
#   titleType            primaryTitle           originalTitle  isAdult  \
# 0     short              Carmencita              Carmencita      0.0
# 1     short  Le clown et ses chiens  Le clown et ses chiens      0.0
# 2     short          Pauvre Pierrot          Pauvre Pierrot      0.0
# 3     short             Un bon bock             Un bon bock      0.0
# 4     short        Blacksmith Scene        Blacksmith Scene      0.0
#
#    startYear                    genres  averageRating  numVotes
# 0     1894.0         Documentary,Short            5.7      1684
# 1     1892.0           Animation,Short            6.0       207
# 2     1892.0  Animation,Comedy,Romance            6.5      1421
# 3     1892.0           Animation,Short            6.1       121
# 4     1893.0              Comedy,Short            6.1      2221

# %%
df_oscar=pd.read_csv('df_oscar_tratado.csv')

# %%
df_oscar.head()
# Out:
#    year_film  year_ceremony  ceremony category                 name  \
# 0       1927           1928         1    ACTOR  Richard Barthelmess
# 1       1927           1928         1    ACTOR        Emil Jannings
# 2       1927           1928         1  ACTRESS       Louise Dresser
# 3       1927           1928         1  ACTRESS         Janet Gaynor
# 4       1927           1928         1  ACTRESS       Gloria Swanson
#
#                film  winner  nominee
# 0         The Noose   False     True
# 1  The Last Command    True     True
# 2   A Ship Comes In   False     True
# 3        7th Heaven    True     True
# 4    Sadie Thompson   False     True

# %%
df_imdb_oscar = df_imdb.merge(df_oscar, left_on=['primaryTitle','startYear'], right_on=['film','year_film'])

# %%
df_imdb_oscar.head()
# Out:
#   titleType                       primaryTitle  \
# 0     movie  The Private Life of Helen of Troy
# 1     movie                    The Jazz Singer
# 2     movie                         7th Heaven
# 3     movie                         7th Heaven
# 4     movie                         7th Heaven
#
#                        originalTitle  isAdult  startYear  \
# 0  The Private Life of Helen of Troy      0.0     1927.0
# 1                    The Jazz Singer      0.0     1927.0
# 2                         7th Heaven      0.0     1927.0
# 3                         7th Heaven      0.0     1927.0
# 4                         7th Heaven      0.0     1927.0
#
#                     genres  averageRating  numVotes  year_film  year_ceremony  \
# 0  Action,Adventure,Comedy            5.8        43       1927           1928
# 1      Drama,Music,Musical            6.5      9093       1927           1928
# 2            Drama,Romance            7.6      3200       1927           1928
# ...

# %%
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
#df_imdb_oscar = df_oscar.merge(df_imdb, left_on=['film','year_film'], right_on=['primaryTitle','startYear'])

# %%
sns.pairplot(df_imdb_oscar,hue='averageRating',palette='bwr')

# %%
df_oscar.head()
# Out:
#    year_film  year_ceremony  ceremony category                 name  \
# 0       1927           1928         1    ACTOR  Richard Barthelmess
# 1       1927           1928         1    ACTOR        Emil Jannings
# 2       1927           1928         1  ACTRESS       Louise Dresser
# 3       1927           1928         1  ACTRESS         Janet Gaynor
# 4       1927           1928         1  ACTRESS       Gloria Swanson
#
#                film  winner  nominee
# 0         The Noose   False     True
# 1  The Last Command    True     True
# 2   A Ship Comes In   False     True
# 3        7th Heaven    True     True
# 4    Sadie Thompson   False     True

# %%
df_oscar.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1a44ed49484d> in <module>
# ----> 1 df_oscar.info()
#
# NameError: name 'df_oscar' is not defined

# %%
sns.heatmap(film)

# %%
df_imdb = pd.read_csv('df_imdb_tratado.csv', sep=',', na_values='\\N', low_memory=False)

# %%
df_imdb
# Out:
#        titleType            primaryTitle                 originalTitle  \
# 0          short              Carmencita                    Carmencita
# 1          short  Le clown et ses chiens        Le clown et ses chiens
# 2          short          Pauvre Pierrot                Pauvre Pierrot
# 3          short             Un bon bock                   Un bon bock
# 4          short        Blacksmith Scene              Blacksmith Scene
# ...          ...                     ...                           ...
# 437563     movie     The Secret of China  Hong xing zhao yao Zhong guo
# 437564   tvMovie               Pink Taxi                     Pink Taxi
# 437565     movie     Kuambil Lagi Hatiku           Kuambil Lagi Hatiku
# 437566     short         My Sweet Prince               My Sweet Prince
# 437567     short               The Nun 2                     The Nun 2
#
#         isAdult  startYear                    genres  averageRating  numVotes
# ...

# %%
df_oscar
# Out:
#        year_film  year_ceremony  ceremony                          category  \
# 0           1927           1928         1                             ACTOR
# 1           1927           1928         1                             ACTOR
# 2           1927           1928         1                           ACTRESS
# 3           1927           1928         1                           ACTRESS
# 4           1927           1928         1                           ACTRESS
# ...          ...            ...       ...                               ...
# 10390       2019           2020        92     WRITING (Original Screenplay)
# 10391       2019           2020        92  JEAN HERSHOLT HUMANITARIAN AWARD
# 10392       2019           2020        92                    HONORARY AWARD
# 10393       2019           2020        92                    HONORARY AWARD
# 10394       2019           2020        92                    HONORARY AWARD
#
# ...

# %%
#df_imdb_oscar = df_oscar.merge(df_imdb, left_on=['film','year_film'], right_on=['primaryTitle','startYear'])

# %%
#df_imdb_oscar.info()

# %%
#df_imdb_oscar
