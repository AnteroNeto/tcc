# %%
import os
os.getcwd()
# Out:
# '/home/antero/Work/notebooks'

# %%
import pandas as pd

# %%
df_oscar=pd.read_csv("../microdados/the_oscar_award.csv", sep=',')

# %%
df_oscar
# Out:
#        year_film  year_ceremony  ceremony                          category  \
# 0           1927           1928         1                             ACTOR
# 1           1927           1928         1                             ACTOR
# 2           1927           1928         1                           ACTRESS
# 3           1927           1928         1                           ACTRESS
# 4           1927           1928         1                           ACTRESS
# ...          ...            ...       ...                               ...
# 10390       2019           2020        92     WRITING (Original Screenplay)
# 10391       2019           2020        92  JEAN HERSHOLT HUMANITARIAN AWARD
# 10392       2019           2020        92                    HONORARY AWARD
# 10393       2019           2020        92                    HONORARY AWARD
# 10394       2019           2020        92                    HONORARY AWARD
#
# ...

# %%
df_oscar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10395 entries, 0 to 10394
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year_film      10395 non-null  int64
#  1   year_ceremony  10395 non-null  int64
#  2   ceremony       10395 non-null  int64
#  3   category       10395 non-null  object
#  4   name           10395 non-null  object
#  5   film           10091 non-null  object
#  6   winner         10395 non-null  bool
# dtypes: bool(1), int64(3), object(3)
# memory usage: 497.5+ KB

# %%
cols_imdb = ['tconst','titleType','primaryTitle','originalTitle', 'genres','startYear']

# %%
df_imdb_basics = pd.read_csv('../microdados/title.basics.tsv', sep='\t', usecols=cols_imdb, na_values='\\N')

# %%
df_imdb_basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 7135028  tt9916848  tvEpisode              Episode #3.17
# 7135029  tt9916850  tvEpisode              Episode #3.19
# 7135030  tt9916852  tvEpisode              Episode #3.20
# 7135031  tt9916856      short                   The Wind
# 7135032  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle  startYear                    genres
# 0                       Carmencita     1894.0         Documentary,Short
# 1           Le clown et ses chiens     1892.0           Animation,Short
# ...

# %%
df_imdb_ratings = pd.read_csv('../microdados/title.ratings.tsv', sep='\t', na_values='\\N')

# %%
df_imdb = df_imdb_basics.merge(df_imdb_ratings,left_on='tconst',right_on='tconst')

# %%
df_imdb
# Out:
#             tconst  titleType                    primaryTitle  \
# 0        tt0000001      short                      Carmencita
# 1        tt0000002      short          Le clown et ses chiens
# 2        tt0000003      short                  Pauvre Pierrot
# 3        tt0000004      short                     Un bon bock
# 4        tt0000005      short                Blacksmith Scene
# ...            ...        ...                             ...
# 1071692  tt9916580  tvEpisode        Horrid Henry Horrid Boy?
# 1071693  tt9916690  tvEpisode  Horrid Henry Delivers the Milk
# 1071694  tt9916720      short                       The Nun 2
# 1071695  tt9916766  tvEpisode                  Episode #10.15
# 1071696  tt9916778  tvEpisode                          Escape
#
#                           originalTitle  startYear                    genres  \
# 0                            Carmencita     1894.0         Documentary,Short
# ...

# %%
df_imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7135033 entries, 0 to 7135032
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   tconst         object
#  1   titleType      object
#  2   primaryTitle   object
#  3   originalTitle  object
#  4   startYear      float64
#  5   genres         object
# dtypes: float64(1), object(5)
# memory usage: 326.6+ MB

# %%
df_imdb.titleType.unique()
# Out:
# array(['short', 'movie', 'tvMovie', 'tvSeries', 'tvEpisode', 'tvShort',
#        'tvMiniSeries', 'tvSpecial', 'video', 'videoGame'], dtype=object)

# %%
df_IMDB_OSCAR = df_oscar.merge(df_imdb_filtered, left_on=['film','year_film'], right_on=['primaryTitle','startYear'])

# %%
type_movie=['movie']

# %%
df_imdb_filtered =df_imdb[df_imdb.titleType.isin(type_movie)]

# %%
df_IMDB_OSCAR = df_oscar.merge(df_imdb_filtered, left_on=['film','year_film'], right_on=['primaryTitle','startYear'])

# %%
df_IMDB_OSCAR
# Out:
#       year_film  year_ceremony  ceremony                       category  \
# 0          1927           1928         1                        ACTRESS
# 1          1927           1928         1                  ART DIRECTION
# 2          1927           1928         1   DIRECTING (Dramatic Picture)
# 3          1927           1928         1            OUTSTANDING PICTURE
# 4          1927           1928         1           WRITING (Adaptation)
# ...         ...            ...       ...                            ...
# 7798       2019           2020        92       SHORT FILM (Live Action)
# 7799       2019           2020        92                   SOUND MIXING
# 7800       2019           2020        92                 VISUAL EFFECTS
# 7801       2019           2020        92                 VISUAL EFFECTS
# 7802       2019           2020        92  WRITING (Original Screenplay)
#
#                                                    name               film  \
# ...

# %%
df_IMDB_OSCAR.to_csv('df_imdb_oscar.csv')
