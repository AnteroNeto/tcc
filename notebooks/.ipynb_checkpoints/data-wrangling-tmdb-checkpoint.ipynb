# %% [markdown]
# # Tratamento de Dados do TMDB

# %%
import os
import pandas as pd
#import pandas_profiling
#conda install -c conda-forge pandas-profiling

# %%
os.chdir("../microdados")
os.getcwd()
# Out:
# '/home/antero/Documentos/TCC/microdados'

# %% [markdown]
# ### Lendo dados do arquivo JSON e importando para o DataFrame do Pandas

# %%
df_tmdb=pd.read_json("movie_ids_02_20_2021.json", lines=True)

# %%
### Explorando o DataFrame

# %%
df_tmdb.shape
# Out:
# (583899, 5)

# %%
df_tmdb.isnull().sum()
# Out:
# adult             0
# id                0
# original_title    0
# popularity        0
# video             0
# dtype: int64

# %%
df_tmdb.isnull().mean()
# Out:
# adult             0.0
# id                0.0
# original_title    0.0
# popularity        0.0
# video             0.0
# dtype: float64

# %%
df_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583899 entries, 0 to 583898
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   adult           583899 non-null  bool
#  1   id              583899 non-null  int64
#  2   original_title  583899 non-null  object
#  3   popularity      583899 non-null  float64
#  4   video           583899 non-null  bool
# dtypes: bool(2), float64(1), int64(1), object(1)
# memory usage: 14.5+ MB

# %%
df_tmdb.head()
# Out:
#    adult     id                      original_title  popularity  video
# 0  False   3924                             Blondie       3.404  False
# 1  False   6124                 Der Mann ohne Namen       0.600  False
# 2  False   8773                 L'amour à vingt ans       3.790  False
# 3  False  25449  New World Disorder 9: Never Enough       2.809  False
# 4  False  31975      Sesame Street: Elmo Loves You!       1.731   True

# %%
df_tmdb.tail()
# Out:
#         adult      id                           original_title  popularity  \
# 583894  False  798749                                 The Plea         0.0
# 583895  False  798750  L’Affaire Cédrika, selon Claude Poirier         0.0
# 583896  False  798751                                     我的姐姐         0.0
# 583897  False  798752        Barbie también puede estar triste         0.0
# 583898  False  798753                                    超能一家人         0.0
#
#         video
# 583894  False
# 583895  False
# 583896  False
# 583897  False
# 583898  False

# %% [markdown]
# ## Salvando Data Frame Tratado

# %%
df_tmdb.to_csv('../tratados/df_tmdb_tratado.csv')

# %%
import os
os.getcwd()
# Out:
# '/home/antero/Work/notebooks'

# %%
import pandas as pd

# %%
df_oscar=pd.read_csv("../microdados/the_oscar_award.csv", sep=',')

# %%
df_oscar
# Out:
#        year_film  year_ceremony  ceremony                          category  \
# 0           1927           1928         1                             ACTOR
# 1           1927           1928         1                             ACTOR
# 2           1927           1928         1                           ACTRESS
# 3           1927           1928         1                           ACTRESS
# 4           1927           1928         1                           ACTRESS
# ...          ...            ...       ...                               ...
# 10390       2019           2020        92     WRITING (Original Screenplay)
# 10391       2019           2020        92  JEAN HERSHOLT HUMANITARIAN AWARD
# 10392       2019           2020        92                    HONORARY AWARD
# 10393       2019           2020        92                    HONORARY AWARD
# 10394       2019           2020        92                    HONORARY AWARD
#
# ...

# %%
df_tmdb=pd.read_json("../microdados/movie_ids_09_05_2020.json", lines=True)

# %%
df_tmdb
# Out:
#         adult      id                      original_title  popularity  video
# 0       False    3924                             Blondie       1.539  False
# 1       False    6124                 Der Mann ohne Namen       0.877  False
# 2       False    8773                 L'amour à vingt ans       2.217  False
# 3       False   21624                    Jatts in Golmaal       0.841  False
# 4       False   25449  New World Disorder 9: Never Enough       0.600  False
# ...       ...     ...                                 ...         ...    ...
# 539921  False  739918                       Pasangan Baru       0.000  False
# 539922  False  739919                       සිරි දළදාගමනය       0.000  False
# 539923  False  739921                             Tസുനാമി       0.000  False
# 539924  False  739922                   The House of Fear       0.000  False
# 539925  False  739923                     Mithila Makhaan       0.000  False
#
# [539926 rows x 5 columns]

# %%
df_oscar_tmdb=df_oscar.merge(df_tmdb, left_on=['film'], right_on='original_title')

# %%
df_oscar_tmdb
# Out:
#        year_film  year_ceremony  ceremony                       category  \
# 0           1927           1928         1                          ACTOR
# 1           1927           1928         1                          ACTOR
# 2           1927           1928         1                          ACTOR
# 3           1927           1928         1       WRITING (Original Story)
# 4           1927           1928         1       WRITING (Original Story)
# ...          ...            ...       ...                            ...
# 19701       2019           2020        92                   SOUND MIXING
# 19702       2019           2020        92                   SOUND MIXING
# 19703       2019           2020        92                   SOUND MIXING
# 19704       2019           2020        92                 VISUAL EFFECTS
# 19705       2019           2020        92  WRITING (Original Screenplay)
#
#                                                     name               film  \
# ...

# %%
df_oscar_tmdb.to_csv('df_tdb_oscar.csv')
